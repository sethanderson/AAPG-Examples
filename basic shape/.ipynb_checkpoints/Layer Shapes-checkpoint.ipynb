# %%
import pandas as pd
import rtree
import geopandas as gpd
from shapely.geometry import Point

# %matplotlib inline

# %% [markdown]
# ### Importing Shape File

# %%
states = gpd.read_file("states/states.shp")

# %%
states.head()
# Out:
#      STATE_NAME  DRAWSEQ STATE_FIPS          SUB_REGION STATE_ABBR  \
# 0        Hawaii        1         15             Pacific         HI
# 1    Washington        2         53             Pacific         WA
# 2       Montana        3         30            Mountain         MT
# 3         Maine        4         23         New England         ME
# 4  North Dakota        5         38  West North Central         ND
#
#                                             geometry
# 0  MULTIPOLYGON (((-160.07380 22.00418, -160.0497...
# 1  MULTIPOLYGON (((-122.40202 48.22522, -122.4628...
# 2  POLYGON ((-111.47543 44.70216, -111.48080 44.6...
# 3  MULTIPOLYGON (((-69.77728 44.07415, -69.85993 ...
# 4  POLYGON ((-98.73044 45.93827, -99.00683 45.939...

# %%
states.plot()
# Out:
# <AxesSubplot:>

# %%
states[states.SUB_REGION == "Pacific"]
# Out:
#     STATE_NAME  DRAWSEQ STATE_FIPS SUB_REGION STATE_ABBR  \
# 0       Hawaii        1         15    Pacific         HI
# 1   Washington        2         53    Pacific         WA
# 11      Oregon       12         41    Pacific         OR
# 24  California       25         06    Pacific         CA
# 50      Alaska       51         02    Pacific         AK
#
#                                              geometry
# 0   MULTIPOLYGON (((-160.07380 22.00418, -160.0497...
# 1   MULTIPOLYGON (((-122.40202 48.22522, -122.4628...
# 11  POLYGON ((-121.44151 41.99433, -122.28471 42.0...
# 24  MULTIPOLYGON (((-121.66522 38.16929, -121.7823...
# 50  MULTIPOLYGON (((-161.33379 58.73325, -161.3824...

# %%
states[states.SUB_REGION == "Pacific"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Importing CSV File

# %%
df = pd.read_csv("database.csv")
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Converting the CSV data to shape points

# %%
points = df.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)

# %%
points
# Out:
# 0           POINT (145.616 19.246)
# 1            POINT (127.352 1.863)
# 2         POINT (-173.972 -20.579)
# 3          POINT (-23.557 -59.076)
# 4           POINT (126.427 11.938)
#                    ...
# 23407    POINT (-118.8941 38.3917)
# 23408    POINT (-118.8957 38.3777)
# 23409     POINT (140.4262 36.9179)
# 23410     POINT (118.6639 -9.0283)
# 23411     POINT (141.4103 37.3973)
# Length: 23412, dtype: object

# %%
quakes = gpd.GeoDataFrame(df, geometry=points)
quakes.crs = {'init': 'epsg:4326'}
quakes.head()
# Out:
# c:\users\sethc\appdata\local\programs\python\python37\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Azimuthal Gap  \
# 0                     NaN        6.0             MW  ...            NaN
# 1                     NaN        5.8             MW  ...            NaN
# 2                     NaN        6.2             MW  ...            NaN
# 3                     NaN        5.8             MW  ...            NaN
# 4                     NaN        5.8             MW  ...            NaN
#
#    Horizontal Distance  Horizontal Error  Root Mean Square            ID  \
# 0                  NaN               NaN               NaN  ISCGEM860706
# 1                  NaN               NaN               NaN  ISCGEM860737
# 2                  NaN               NaN               NaN  ISCGEM860762
# 3                  NaN               NaN               NaN  ISCGEM860856
# 4                  NaN               NaN               NaN  ISCGEM860890
#
#    Source Location Source Magnitude Source     Status  \
# 0  ISCGEM          ISCGEM           ISCGEM  Automatic
# 1  ISCGEM          ISCGEM           ISCGEM  Automatic
# 2  ISCGEM          ISCGEM           ISCGEM  Automatic
# 3  ISCGEM          ISCGEM           ISCGEM  Automatic
# 4  ISCGEM          ISCGEM           ISCGEM  Automatic
#
#                        geometry
# 0    POINT (145.61600 19.24600)
# 1     POINT (127.35200 1.86300)
# 2  POINT (-173.97200 -20.57900)
# 3   POINT (-23.55700 -59.07600)
# 4    POINT (126.42700 11.93800)
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Plotting Data

# %%
quakes.plot()
# Out:
# <AxesSubplot:>

# %%
states.to_crs(quakes.crs, inplace=True)

# %%
quakes_on_states = gpd.sjoin(quakes, states, op="intersects")
quakes_on_states.head()
# Out:
#            Date      Time  Latitude  Longitude        Type  Depth  \
# 123  04/16/1965  23:22:21    64.572   -160.375  Earthquake   15.0
# 187  06/27/1965  11:08:59    60.281   -141.418  Earthquake   15.0
# 250  09/04/1965  14:32:51    58.090   -152.525  Earthquake   27.8
# 251  09/08/1965  03:26:22    57.513   -152.263  Earthquake   25.0
# 531  10/07/1966  20:55:57    61.580   -150.126  Earthquake   55.0
#
#      Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 123          NaN                     NaN        6.0             MW  ...
# 187          NaN                     NaN        6.5             MW  ...
# 250          NaN                     NaN        7.0             MW  ...
# 251          NaN                     NaN        5.7             MW  ...
# 531          NaN                     NaN        5.6             MW  ...
#
#      Location Source  Magnitude Source     Status  \
# 123           ISCGEM            ISCGEM  Automatic
# 187           ISCGEM            ISCGEM  Automatic
# 250           ISCGEM            ISCGEM  Automatic
# 251           ISCGEM            ISCGEM  Automatic
# 531           ISCGEM            ISCGEM  Automatic
#
#                         geometry  index_right  STATE_NAME DRAWSEQ STATE_FIPS  \
# 123  POINT (-160.37500 64.57200)           50      Alaska      51         02
# 187  POINT (-141.41800 60.28100)           50      Alaska      51         02
# 250  POINT (-152.52500 58.09000)           50      Alaska      51         02
# 251  POINT (-152.26300 57.51300)           50      Alaska      51         02
# 531  POINT (-150.12600 61.58000)           50      Alaska      51         02
#
#     SUB_REGION STATE_ABBR
# 123    Pacific         AK
# 187    Pacific         AK
# 250    Pacific         AK
# 251    Pacific         AK
# 531    Pacific         AK
#
# [5 rows x 28 columns]

# %%
states_plot = states.plot()

# %%
quakes_plot = quakes.plot(edgecolor='yellow')

# %%
import matplotlib.pyplot as plt

# %%
pacific_states = states[states.SUB_REGION == "Pacific"]

# %%
fig, ax = plt.subplots() 
# states.plot(column='STATE_NAME',cmap='Purples',ax=ax)
pacific_states.plot(ax=ax, edgecolor="black")
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots() 
# pacific_states.plot(column='STATE_NAME',cmap='Purples',ax=ax)
pacific_states.plot(color=None,edgecolor='k',ax=ax)
quakes.plot(ax=ax, edgecolor='yellow')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(15,15)) 

# pacific_states.plot(column='STATE_NAME',cmap='Purples',ax=ax)
pacific_states.plot(color='grey',edgecolor='white',ax=ax)
quakes_on_states.plot(ax=ax, color='blue', markersize=3)
# Out:
# <AxesSubplot:>
